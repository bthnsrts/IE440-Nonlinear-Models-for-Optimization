# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def vector_length(x):
    return np.sqrt(x@x)

# %%
def Golden_Section(f, a, b, epsilon):
    gamma = (1 + np.sqrt(5))/2  
    c = 1/gamma
    
    x = b - c*(b-a) # defining the x_0
    y = a + c*(b-a) # defining the y_0
    
    fx = f(x)       # defining the f(x_0)
    fy = f(y)       # defining the f(y_0)

    while abs(b-a) > epsilon:
        if fx > fy: 
            a = x
            x = y
            fx = fy 
            
            y = a + c*(b-a) 
            fy = f(y)
            
        else:
            b = y  
            y = x  
            fy = fx  
            
            x = b - c*(b-a)
            fx = f(x)
         
    return x

# %%
#the first function
def f1(x):
    return np.power(5*x[0]-x[1],4) + np.power(x[0]-2,2) + x[0] - 2*x[1] + 12

def df1(x):
    dx1 = 20*np.power(5*x[0]-x[1],3) + 2*(x[0]-2) + 1
    dx2 = -4*np.power(5*x[0]-x[1],3) - 2
    return np.array([dx1,dx2])
    
#the second function
def f2(x):
    return 100*np.power(x[1]-np.power(x[0],2),2) + np.power(1-x[0],2)
def df2(x):
    dx1 = 400*(np.power(x[0],3) - x[0]*x[1]) + 2 * (x[0]-1)
    dx2 = 200*(x[1]-np.power(x[0],2))
    return np.array([dx1,dx2])

# %%
def SteepestDescentMethod(f,df,x_0, epsilon,iterations):
    list_x = [x_0]    #hold x values
    list_fx = []      #hold f(x) values
    list_d = []       #hold directions
    list_alpha = []   #hold alpha values
    i=0
    
    while vector_length(df(list_x[-1]))>epsilon:
        i+=1
        x = list_x[-1]             #take new x from the previous iteration
        list_fx.append(f(x))       #calculate and store f(x)
        
        df_k = df(x)               #calculate the gradient of the function at 
        d_k = -df_k          #calculate the direction
        list_d.append(d_k)         #store direction
        
        def f_line(a):
            return f(x+a*d_k)      #this function is for the exact line search below
        
        alpha = Golden_Section(f_line, -100, 100, epsilon*1e-1) #find the alpha that minimizes f_line
        list_alpha.append(alpha)   #store alpha
        
        x_new = x + alpha * d_k    #find new x
        list_x.append(x_new)       #store new x
        
        if i==iterations:
            break
                     
    
    output = pd.DataFrame({'x(k)':list_x[:-1],'f(x(k))':list_fx,'d(k)':list_d,'alpha(k)':list_alpha,'x(k+1)':list_x[1:]})
    return output, np.array(list_x)

# %%
output1,x1 = SteepestDescentMethod(f1,df1, np.array([12,-100]), 0.0001,1000)
output1
# Out:
#                                           x(k)       f(x(k))  \
# 0                                   [12, -100]  6.553603e+08
# 1     [-45.92580681674215, -88.41484019227586]  3.976638e+08
# 2     [-6.101537394982863, -96.37967924847158]  1.882822e+07
# 3    [-10.143695284795536, -95.57124410628036]  4.047562e+06
# 4     [-11.41976431430987, -95.31602559286172]  2.133591e+06
# ..                                         ...           ...
# 167    [6.4966572130654585, 33.27421332847172] -2.744051e+01
# 168    [6.496162800878131, 33.274318972458225] -2.744054e+01
# 169     [6.499650363580462, 33.29243072305132] -2.744055e+01
# 170    [6.4997449828953195, 33.29241250337649] -2.744055e+01
# 171     [6.499906171073975, 33.29316133396528] -2.744055e+01
#
#                                                 d(k)      alpha(k)  \
# 0                              [-81920021, 16384002]  7.071020e-07
# 1           [56320406.51002645, -11264060.331682563]  7.071020e-07
# 2           [-5716513.544064494, 1143307.7494278566]  7.071020e-07
# 3           [-1804646.4510365722, 360935.9476854284]  7.071020e-07
# 4          [-1116340.4867191801, 223275.26524956175]  6.697766e-06
# ..                                               ...           ...
# 167      [-0.09777135915632762, 0.02089138660508194]  5.056820e-03
# 168  [0.00028459323353224875, 0.0014779610020410061]  1.225455e+01
# 169   [0.018791772560868836, -0.0036184999443582555]  5.035146e-03
# 170   [2.1051038226360674e-05, 9.77966342270431e-05]  7.657018e+00
# 171   [-0.002459733876071013, 0.0005294783456242236]  5.041136e-03
#
#                                         x(k+1)
# 0     [-45.92580681674215, -88.41484019227586]
# 1     [-6.101537394982863, -96.37967924847158]
# 2    [-10.143695284795536, -95.57124410628036]
# 3     [-11.41976431430987, -95.31602559286172]
# 4     [-18.896751383544835, -93.8205801700613]
# ..                                         ...
# 167    [6.496162800878131, 33.274318972458225]
# 168     [6.499650363580462, 33.29243072305132]
# 169    [6.4997449828953195, 33.29241250337649]
# 170     [6.499906171073975, 33.29316133396528]
# 171     [6.499893771219818, 33.29316400313788]
#
# [172 rows x 5 columns]

# %%
blue = np.array([0.,0.,1])
red = np.array([1.,0.,0.])
def color_gradient(n, c1=red, c2=blue):
    c = []
    for i in range(n):
        k = i/n
        c.append(k*c1+(1-k)*c2)
    return np.array(c)

# %%
plt.scatter(x1[:,0], x1[:,1], c = color_gradient(x1.shape[0]))

# %%
output2, x2 = SteepestDescentMethod(f2,df2, np.array([-5,10]), 0.0001,1e4)
output2
# Out:
#                                            x(k)       f(x(k))  \
# 0                                      [-5, 10]  22536.000000
# 1     [-3.2757660671895135, 10.172354451500448]     49.450822
# 2        [3.34066743593141, 11.170591415236892]      5.489817
# 3      [-3.565507893979767, 12.719406421929772]     20.848166
# 4        [9.404156886874242, 88.44464850709326]     70.634054
# ...                                         ...           ...
# 9995   [-45.983293881445185, 2114.468309906591]   2207.432398
# 9996   [-45.98329238555398, 2114.4683092003775]   2207.432396
# 9997    [-45.98329266973249, 2114.468308474808]   2207.432395
# 9998   [-45.98328414279413, 2114.4682140340187]   2207.432345
# 9999    [-45.98329304851156, 2114.468213214703]   2207.432299
#
#                                              d(k)      alpha(k)  \
# 0                                   [30012, 3000]  5.745148e-05
# 1         [740.0810336895232, 111.65777508996086]  8.940147e-03
# 2        [9.392894021566288, -2.1064995488703886] -7.352553e-01
# 3     [-0.22470563562058743, -1.3119759795479524] -5.771847e+01
# 4        [7.573859394102367, -1.2963508298042825] -2.505929e+00
# ...                                           ...           ...
# 9995     [2.1155240732077374, -0.998743847321748]  7.071020e-07
# 9996    [-0.401891859080564, -1.0261170061312441]  7.071019e-07
# 9997   [0.09216175526267989, -1.0207449067820562]  9.252144e-05
# 9998   [-12.594672745570449, -1.1586954152335238]  7.071019e-07
# 9999    [2.4850426017033413, -0.9947258822649019]  7.071020e-07
#
#                                          x(k+1)
# 0     [-3.2757660671895135, 10.172354451500448]
# 1        [3.34066743593141, 11.170591415236892]
# 2      [-3.565507893979767, 12.719406421929772]
# 3        [9.404156886874242, 88.44464850709326]
# 4        [-9.575397220556171, 91.6932116815881]
# ...                                         ...
# 9995   [-45.98329238555398, 2114.4683092003775]
# 9996    [-45.98329266973249, 2114.468308474808]
# 9997   [-45.98328414279413, 2114.4682140340187]
# 9998    [-45.98329304851156, 2114.468213214703]
# 9999   [-45.98329129133309, 2114.4682125113304]
#
# [10000 rows x 5 columns]

# %%
plt.scatter(x2[:,0], x2[:,1], c = color_gradient(x2.shape[0], blue, red))
